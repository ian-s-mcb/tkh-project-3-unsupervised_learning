# %% [markdown]
# # tkh-project-3-unsupervised_learning - Model notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Load dataset
#
# Here we see that we 24 columns in dataset and no missing values.

# %%
df_orig = pd.read_csv('../data/formatted.csv')
df_orig.info()
